# %% [markdown]
# # COLLECTIONS

# %%
from collections import Counter

# %%
a = Counter()
b = Counter('abrakadabra')
c = Counter({'red': 2, 'blue': 3})
d = Counter(cats=2, dogs=5)

print(a, b, c, d, sep='\n')
# Out:
# Counter()
# Counter({'a': 5, 'b': 2, 'r': 2, 'k': 1, 'd': 1})
# Counter({'blue': 3, 'red': 2})
# Counter({'dogs': 5, 'cats': 2})

# %%
print(b['z'])
# Out:
# 0

# %%
b['z'] = 0
b
# Out:
# Counter({'a': 5, 'b': 2, 'r': 2, 'k': 1, 'd': 1, 'z': 0})

# %%
print(list(b.elements()))
# Out:
# ['a', 'a', 'a', 'a', 'a', 'b', 'b', 'r', 'r', 'k', 'd']

# %%
print(b.most_common(2))
# Out:
# [('a', 5), ('b', 2)]

# %%
g = Counter(a=4, b=6, c=-2, d=0)
f = Counter(a=1, b=2, c=3, d=-2)
g.subtract(f)
print(g)
# Out:
# Counter({'b': 4, 'a': 3, 'd': 2, 'c': -5})

# %%
set(g)
# Out:
# {'a', 'b', 'c', 'd'}

# %%
dict(g)
# Out:
# {'a': 3, 'b': 4, 'c': -5, 'd': 2}

# %%
g.clear()
g
# Out:
# Counter()

# %%
x = Counter(a=3, b=1)
y = Counter(a=1, b=2)

print(x + y)
print(x - y)  # на экран выводятся те, которые положительные
print(x & y)
print(x | y)
# Out:
# Counter({'a': 4, 'b': 3})
# Counter({'a': 2})
# Counter({'a': 1, 'b': 1})
# Counter({'a': 3, 'b': 2})

# %%
z = Counter(a=2, b=-4)
print(+z)  # оставляет только положительные элементы
print(-z)  # оставляет только отрицательные элементы, при этом меняет у них знак
# Out:
# Counter({'a': 2})
# Counter({'b': 4})

# %% [markdown]
# # DEQUE

# %%
from collections import deque

# %%
a = deque()
b = deque('abcdef')
c = deque([1, 2, 3, 4, 5])
print(a, b, c, sep='\n')
# Out:
# deque([])
# deque(['a', 'b', 'c', 'd', 'e', 'f'])
# deque([1, 2, 3, 4, 5])

# %% [markdown]
# #### maxlen

# %%
b = deque('abcdef', maxlen=3)  # остаются последние элементы!!!
c = deque([1, 2, 3, 4, 5], maxlen=4)
print(b, c, sep='\n')
# Out:
# deque(['d', 'e', 'f'], maxlen=3)
# deque([2, 3, 4, 5], maxlen=4)

# %% [markdown]
# #### очистка очереди

# %%
c.clear()
c
# Out:
# deque([])

# %% [markdown]
# #### добавление элемента

# %%
d = deque([i for i in range(5)])
d
# Out:
# deque([0, 1, 2, 3, 4])

# %%
d.append(5)
d
# Out:
# deque([0, 1, 2, 3, 4, 5])

# %%
d.appendleft(6)
d
# Out:
# deque([6, 0, 1, 2, 3, 4, 5])

# %%
d.extend([7, 8, 9])
d
# Out:
# deque([6, 0, 1, 2, 3, 4, 5, 7, 8, 9])

# %%
d.extendleft([11, 12, 13])  # добавляет с разворотом добавляемого списка!!!
d
# Out:
# deque([13, 12, 11, 6, 0, 1, 2, 3, 4, 5, 7, 8, 9])

# %% [markdown]
# #### добавление элементов и maxlen

# %%
d = deque([i for i in range(5)], maxlen=7)
d
# Out:
# deque([0, 1, 2, 3, 4])

# %%
d.extend([7, 8, 9])
d
# Out:
# deque([1, 2, 3, 4, 7, 8, 9])

# %% [markdown]
# убирается 0

# %%
d.extendleft([11, 12, 13])
d
# Out:
# deque([13, 12, 11, 1, 2, 3, 4])

# %% [markdown]
# убираются 7, 8, 9

# %% [markdown]
# #### убирание элемента

# %%
f = deque([i for i in range(5)], maxlen=7)
f
# Out:
# deque([0, 1, 2, 3, 4])

# %%
x = f.pop()
y = f.popleft()
x, y, f
# Out:
# (4, 0, deque([1, 2, 3]))

# %% [markdown]
# #### подсчёт количества элементов с определённым значением

# %%
f.count(0), f.count(1)
# Out:
# (0, 1)

# %% [markdown]
# #### нахождение индекса элемента по его значению

# %%
f.index(2)
# Out:
# 1

# %% [markdown]
# #### вставка элемента

# %%
f
# Out:
# deque([1, 2, 3])

# %%
f.insert(0, 111)  # 0 - индекс элемента куда вставить значение
f
# Out:
# deque([111, 1, 2, 3])

# %% [markdown]
# #### разворот списка

# %%
f.reverse()
f
# Out:
# deque([3, 2, 1, 111])

# %% [markdown]
# #### поменять n элементов справа и слева местами

# %%
f.rotate(2)
f
# Out:
# deque([1, 111, 3, 2])

# %%
f.rotate(-2)
f
# Out:
# deque([3, 2, 1, 111])

# %% [markdown]
# # РАЗДЕЛЕНИЕ СПИСКА НА ПОЛОЖИТЕЛЬНЫЕ И ОТРИЦАТЕЛЬНЫЕ ЭЛЕМЕНТЫ

# %%
import random

array = [random.randint(-100, 100) for _ in range(10)]
array
# Out:
# [24, -37, -98, -35, -83, 20, 86, -4, -14, 84]

# %%
deq = deque()

for item in array:
    if item > 0:
        deq.append(item)
    elif item < 0:
        deq.appendleft(item)

# %%
deq
# Out:
# deque([-14, -4, -83, -35, -98, -37, 24, 20, 86, 84])

# %% [markdown]
# # DEFAULTDICT

# %%
from collections import defaultdict

# %%
a = defaultdict()
a
# Out:
# defaultdict(None, {})

# %%
s = 'qwertyuiop'
b = defaultdict(int)
for i in s:
    b[i] += 1  # по дефолту присваивается 0, а к нему уже прибавляется 1

# %%
b
# Out:
# defaultdict(int,
#             {'q': 1,
#              'w': 1,
#              'e': 1,
#              'r': 1,
#              't': 1,
#              'y': 1,
#              'u': 1,
#              'i': 1,
#              'o': 1,
#              'p': 1})

# %%
list_1 = [('cat', 1), ('dog', 5), ('cat', 2), ('mouse', 1), ('dog', 1)]
c = defaultdict(list)
for k, v in list_1:
    c[k].append(v)
c
# Out:
# defaultdict(list, {'cat': [1, 2], 'dog': [5, 1], 'mouse': [1]})

# %% [markdown]
# добавились все переменные для каждого ключа

# %%
list_1 = [('cat', 1), ('dog', 5), ('cat', 2), ('mouse', 1), ('dog', 1), ('cat', 1), ('dog', 5)]
c = defaultdict(set)
for k, v in list_1:
    c[k].add(v)
c
# Out:
# defaultdict(set, {'cat': {1, 2}, 'dog': {1, 5}, 'mouse': {1}})

# %% [markdown]
# добавились все уникальные переменные для каждого ключа

# %%
f = defaultdict(lambda: 'unknown')
f.update(rex='dog', tomas='cat')
print(f)
print(f['rex'])
print(f['jerry'])
# Out:
# defaultdict(<function <lambda> at 0x00000252431A8040>, {'rex': 'dog', 'tomas': 'cat'})
# dog
# unknown

# %% [markdown]
# # OrderedDict

# %%
from collections import OrderedDict

# %%
a = {'cat': 5, 'mouse': 4, 'dog': 2}
new_a = OrderedDict(sorted(a.items(), key=lambda x: x[0]))  # сортирует по ключам, по алфавиту
print(new_a)

b = {'cat': 5, 'mouse': 4, 'dog': 2}
new_b = OrderedDict(sorted(a.items(), key=lambda x: x[1]))  # сортирует по значениям
print(new_b)

print(new_a == new_b)
# Out:
# OrderedDict([('cat', 5), ('dog', 2), ('mouse', 4)])
# OrderedDict([('dog', 2), ('mouse', 4), ('cat', 5)])
# False

# %% [markdown]
# обычные словари были бы равны

# %%
new_b.move_to_end('mouse')
new_b
# Out:
# OrderedDict([('dog', 2), ('cat', 5), ('mouse', 4)])

# %%
new_b.move_to_end('mouse', last=False)
new_b
# Out:
# OrderedDict([('mouse', 4), ('dog', 2), ('cat', 5)])

# %%
new_b.popitem()
print(new_b)
# Out:
# OrderedDict([('mouse', 4), ('dog', 2)])

# %%
new_b['cow'] = 1
print(new_b)
# Out:
# OrderedDict([('mouse', 4), ('dog', 2), ('cow', 1)])

# %%
new_b['dog'] = 8
print(new_b)
# Out:
# OrderedDict([('mouse', 4), ('dog', 8), ('cow', 1)])

# %%
a = {'cat': 5, 'mouse': 4, 'parrot': 2}
new_c = OrderedDict(sorted(a.items(), key=lambda x: len(x[0])))  # сортирует по значениям
print(new_c)
# Out:
# OrderedDict([('cat', 5), ('mouse', 4), ('parrot', 2)])

# %%
from collections import OrderedDict, defaultdict, deque


N = 3000  # 3000 последних адресов в списке

with open('big_log.txt', 'r', encoding='utf-8') as f:
    log = deque(f, N)
    
# print(log)

spam = defaultdict(int)
data = OrderedDict()


for item in log:
    ip = item[:-1]
    
    if not ip.startswith('192.168'):
        spam[ip] += 1  # считает количество повторений
        data[ip] = 1  # запоминает порядок

# print('SPAM')
# print(spam)
# print('\n' * 50)
# print('DATA')
# print(data)
# print('\n' * 50)

data.update(spam)  # добавляет количество повторений к запомненному порядку
# print(data)

with open('data.txt', 'w', encoding='utf-8') as f:
          for key, value in data.items():
              f.write(f'{key} - {value}\n')
                
#  на выходе имеем список не локальных ip адресов выбранный из последних 3000 адресов 
#  также указано количество обращений по этим адресам
# Out:
# SPAM
# defaultdict(<class 'int'>, {'195.170.6.29': 1, '195.170.8.8': 1, '200.164.4.4': 1, '190.167.8.31': 1, '193.161.8.21': 1, '183.166.4.30': 1, '192.166.7.16': 2, '186.163.4.21': 1, '196.164.8.13': 1, '196.160.6.14': 1, '197.162.2.15': 1, '194.168.1.17': 1, '198.169.3.2': 1, '193.164.8.17': 1, '183.165.8.2': 1, '189.167.8.13': 1, '188.167.3.26': 1, '189.167.6.31': 1, '185.162.5.5': 1, '183.170.6.18': 1, '195.160.1.7': 1, '200.165.4.13': 1, '197.167.6.16': 1, '199.161.6.17': 1, '195.165.8.21': 1, '194.169.8.2': 1, '198.167.1.1': 1, '185.168.2.11': 1, '200.161.4.10': 1, '195.165.3.14': 1, '180.170.3.5': 1, '188.161.8.18': 1, '197.160.1.24': 1, '187.165.1.3': 1, '185.166.1.17': 1, '186.161.8.24': 1, '192.165.7.23': 2, '182.169.2.2': 1, '185.162.1.18': 1, '194.165.5.30': 1, '190.161.1.6': 1, '192.164.7.1': 1, '198.162.7.11': 1, '196.160.4.19': 1, '197.161.4.9': 1, '183.167.2.13': 1, '186.167.2.1': 1, '193.161.2.11': 1, '183.162.5.8': 1, '193.164.5.13': 1, '182.168.6.19': 1, '195.169.3.6': 1, '187.165.8.7': 1, '186.163.1.14': 1, '199.165.4.9': 1, '198.161.6.31': 1, '185.161.4.20': 1, '192.160.4.19': 1, '196.169.3.20': 1, '199.165.1.6': 1, '195.166.6.26': 1, '200.168.3.3': 1, '185.161.6.9': 1, '181.169.1.12': 1, '191.162.2.17': 1, '186.167.1.12': 1, '192.165.7.11': 1, '198.164.1.28': 1, '198.160.8.15': 1, '183.160.5.8': 1, '185.164.6.1': 1, '182.163.2.13': 1, '183.170.8.8': 1, '200.166.3.20': 1, '193.169.6.14': 1, '196.163.6.20': 2, '194.168.4.12': 1, '182.164.1.3': 1, '194.168.3.11': 1, '181.161.3.9': 1, '181.169.6.16': 1, '183.168.2.26': 1, '194.166.8.9': 1, '194.162.3.9': 1, '181.165.3.11': 1, '194.167.6.4': 1, '199.166.6.22': 1, '187.169.3.28': 1, '199.164.5.4': 1, '193.162.2.27': 1, '183.168.2.2': 1, '193.168.3.30': 1, '200.167.5.5': 1, '199.161.7.13': 1, '189.161.2.11': 1, '188.164.3.9': 1, '184.169.3.32': 1, '181.165.8.28': 2, '184.162.7.2': 1, '191.167.6.24': 1, '198.166.7.3': 1, '196.169.6.13': 1, '184.166.2.22': 1, '193.167.5.10': 1, '198.166.3.7': 1, '194.165.4.8': 1, '188.166.6.19': 1, '194.161.4.15': 1, '191.167.6.14': 1, '195.167.4.10': 1, '199.168.7.18': 1, '191.161.7.27': 1, '180.163.7.28': 1, '194.166.2.2': 1, '183.170.7.10': 1, '183.164.8.17': 1, '198.164.2.27': 1, '182.169.2.19': 1, '200.166.2.2': 1, '190.165.7.15': 1, '193.166.8.12': 1, '183.164.5.16': 1, '187.166.1.6': 1, '195.160.6.20': 2, '185.170.5.26': 1, '194.170.5.6': 1, '197.164.8.3': 1, '194.166.8.30': 1, '194.163.2.6': 1, '180.168.8.13': 1, '185.169.6.15': 1, '193.160.5.9': 1, '191.164.5.9': 1, '184.170.2.2': 1, '196.168.4.22': 1, '187.162.7.7': 1, '193.168.8.8': 1, '185.166.7.17': 1, '188.168.1.26': 1, '187.164.2.1': 1, '180.166.2.20': 1, '187.169.7.21': 1, '198.168.8.12': 1, '184.160.6.15': 1, '200.168.6.29': 1, '181.161.8.15': 1, '188.166.7.18': 1, '184.162.3.28': 1, '192.169.3.30': 1, '190.167.7.22': 1, '199.165.1.22': 1, '198.161.2.5': 1, '200.167.4.1': 1, '181.162.3.5': 1, '182.167.1.4': 1, '192.170.5.27': 1, '192.163.5.30': 2, '197.168.7.26': 1, '196.162.4.30': 1, '200.169.5.13': 1, '180.170.6.32': 1, '196.164.6.12': 1, '184.164.3.8': 1, '184.167.5.3': 1, '192.161.3.1': 1, '195.164.2.31': 1, '195.169.3.21': 1, '183.170.7.2': 1, '184.166.2.10': 1, '182.166.3.21': 1, '191.161.8.1': 1, '194.161.3.26': 1, '188.163.2.22': 1, '192.161.7.8': 1, '189.164.7.26': 1, '193.168.1.7': 1, '197.164.4.20': 1, '192.170.7.15': 1, '189.167.2.27': 2, '185.165.5.11': 1, '198.163.3.20': 1, '194.163.5.1': 1, '191.163.2.9': 1, '200.167.3.10': 1, '182.161.8.14': 1, '200.161.8.3': 1, '194.163.3.25': 1, '183.170.7.3': 1, '192.165.1.13': 1, '198.168.2.5': 1, '187.160.6.25': 1, '181.160.7.31': 1, '180.168.1.7': 1, '194.167.4.2': 1, '182.169.1.16': 1, '191.161.1.26': 1, '182.165.7.2': 1, '182.167.2.25': 2, '194.169.6.12': 1, '194.168.7.25': 1, '190.166.4.4': 1, '182.169.6.29': 1, '185.166.5.10': 1, '188.167.8.16': 1, '183.161.7.7': 1, '189.162.1.23': 1, '183.169.5.20': 1, '195.165.3.6': 1, '189.160.6.32': 1, '185.166.1.3': 1, '183.162.3.29': 1, '188.160.1.8': 1, '191.164.4.2': 1,  ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# DATA
# OrderedDict([('195.170.6.29', 1), ('195.170.8.8', 1), ('200.164.4.4', 1), ('190.167.8.31', 1), ('193.161.8.21', 1), ('183.166.4.30', 1), ('192.166.7.16', 1), ('186.163.4.21', 1), ('196.164.8.13', 1), ('196.160.6.14', 1), ('197.162.2.15', 1), ('194.168.1.17', 1), ('198.169.3.2', 1), ('193.164.8.17', 1), ('183.165.8.2', 1), ('189.167.8.13', 1), ('188.167.3.26', 1), ('189.167.6.31', 1), ('185.162.5.5', 1), ('183.170.6.18', 1), ('195.160.1.7', 1), ('200.165.4.13', 1), ('197.167.6.16', 1), ('199.161.6.17', 1), ('195.165.8.21', 1), ('194.169.8.2', 1), ('198.167.1.1', 1), ('185.168.2.11', 1), ('200.161.4.10', 1), ('195.165.3.14', 1), ('180.170.3.5', 1), ('188.161.8.18', 1), ('197.160.1.24', 1), ('187.165.1.3', 1), ('185.166.1.17', 1), ('186.161.8.24', 1), ('192.165.7.23', 1), ('182.169.2.2', 1), ('185.162.1.18', 1), ('194.165.5.30', 1), ('190.161.1.6', 1), ('192.164.7.1', 1), ('198.162.7.11', 1), ('196.160.4.19', 1), ('197.161.4.9', 1), ('183.167.2.13', 1), ('186.167.2.1', 1), ('193.161.2.11', 1), ('183.162.5.8', 1), ('193.164.5.13', 1), ('182.168.6.19', 1), ('195.169.3.6', 1), ('187.165.8.7', 1), ('186.163.1.14', 1), ('199.165.4.9', 1), ('198.161.6.31', 1), ('185.161.4.20', 1), ('192.160.4.19', 1), ('196.169.3.20', 1), ('199.165.1.6', 1), ('195.166.6.26', 1), ('200.168.3.3', 1), ('185.161.6.9', 1), ('181.169.1.12', 1), ('191.162.2.17', 1), ('186.167.1.12', 1), ('192.165.7.11', 1), ('198.164.1.28', 1), ('198.160.8.15', 1), ('183.160.5.8', 1), ('185.164.6.1', 1), ('182.163.2.13', 1), ('183.170.8.8', 1), ('200.166.3.20', 1), ('193.169.6.14', 1), ('196.163.6.20', 1), ('194.168.4.12', 1), ('182.164.1.3', 1), ('194.168.3.11', 1), ('181.161.3.9', 1), ('181.169.6.16', 1), ('183.168.2.26', 1), ('194.166.8.9', 1), ('194.162.3.9', 1), ('181.165.3.11', 1), ('194.167.6.4', 1), ('199.166.6.22', 1), ('187.169.3.28', 1), ('199.164.5.4', 1), ('193.162.2.27', 1), ('183.168.2.2', 1), ('193.168.3.30', 1), ('200.167.5.5', 1), ('199.161.7.13', 1), ('189.161.2.11', 1), ('188.164.3.9', 1), ('184.169.3.32', 1), ('181.165.8.28', 1), ('184.162.7.2', 1), ('191.167.6.24', 1), ('198.166.7.3', 1), ('196.169.6.13', 1), ('184.166.2.22', 1), ('193.167.5.10', 1), ('198.166.3.7', 1), ('194.165.4.8', 1), ('188.166.6.19', 1), ('194.161.4.15', 1), ('191.167.6.14', 1), ('195.167.4.10', 1), ('199.168.7.18', 1), ('191.161.7.27', 1), ('180.163.7.28', 1), ('194.166.2.2', 1), ('183.170.7.10', 1), ('183.164.8.17', 1), ('198.164.2.27', 1), ('182.169.2.19', 1), ('200.166.2.2', 1), ('190.165.7.15', 1), ('193.166.8.12', 1), ('183.164.5.16', 1), ('187.166.1.6', 1), ('195.160.6.20', 1), ('185.170.5.26', 1), ('194.170.5.6', 1), ('197.164.8.3', 1), ('194.166.8.30', 1), ('194.163.2.6', 1), ('180.168.8.13', 1), ('185.169.6.15', 1), ('193.160.5.9', 1), ('191.164.5.9', 1), ('184.170.2.2', 1), ('196.168.4.22', 1), ('187.162.7.7', 1), ('193.168.8.8', 1), ('185.166.7.17', 1), ('188.168.1.26', 1), ('187.164.2.1', 1), ('180.166.2.20', 1), ('187.169.7.21', 1), ('198.168.8.12', 1), ('184.160.6.15', 1), ('200.168.6.29', 1), ('181.161.8.15', 1), ('188.166.7.18', 1), ('184.162.3.28', 1), ('192.169.3.30', 1), ('190.167.7.22', 1), ('199.165.1.22', 1), ('198.161.2.5', 1), ('200.167.4.1', 1), ('181.162.3.5', 1), ('182.167.1.4', 1), ('192.170.5.27', 1), ('192.163.5.30', 1), ('197.168.7.26', 1), ('196.162.4.30', 1), ('200.169.5.13', 1), ('180.170.6.32', 1), ('196.164.6.12', 1), ('184.164.3.8', 1), ('184.167.5.3', 1), ('192.161.3.1', 1), ('195.164.2.31', 1), ('195.169.3.21', 1), ('183.170.7.2', 1), ('184.166.2.10', 1), ('182.166.3.21', 1), ('191.161.8.1', 1), ('194.161.3.26', 1), ('188.163.2.22', 1), ('192.161.7.8', 1), ('189.164.7.26', 1), ('193.168.1.7', 1), ('197.164.4.20', 1), ('192.170.7.15', 1), ('189.167.2.27', 1), ('185.165.5.11', 1), ('198.163.3.20', 1), ('194.163.5.1', 1), ('191.163.2.9', 1), ('200.167.3.10', 1), ('182.161.8.14', 1), ('200.161.8.3', 1), ('194.163.3.25', 1), ('183.170.7.3', 1), ('192.165.1.13', 1), ('198.168.2.5', 1), ('187.160.6.25', 1), ('181.160.7.31', 1), ('180.168.1.7', 1), ( ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# OrderedDict([('195.170.6.29', 1), ('195.170.8.8', 1), ('200.164.4.4', 1), ('190.167.8.31', 1), ('193.161.8.21', 1), ('183.166.4.30', 1), ('192.166.7.16', 2), ('186.163.4.21', 1), ('196.164.8.13', 1), ('196.160.6.14', 1), ('197.162.2.15', 1), ('194.168.1.17', 1), ('198.169.3.2', 1), ('193.164.8.17', 1), ('183.165.8.2', 1), ('189.167.8.13', 1), ('188.167.3.26', 1), ('189.167.6.31', 1), ('185.162.5.5', 1), ('183.170.6.18', 1), ('195.160.1.7', 1), ('200.165.4.13', 1), ('197.167.6.16', 1), ('199.161.6.17', 1), ('195.165.8.21', 1), ('194.169.8.2', 1), ('198.167.1.1', 1), ('185.168.2.11', 1), ('200.161.4.10', 1), ('195.165.3.14', 1), ('180.170.3.5', 1), ('188.161.8.18', 1), ('197.160.1.24', 1), ('187.165.1.3', 1), ('185.166.1.17', 1), ('186.161.8.24', 1), ('192.165.7.23', 2), ('182.169.2.2', 1), ('185.162.1.18', 1), ('194.165.5.30', 1), ('190.161.1.6', 1), ('192.164.7.1', 1), ('198.162.7.11', 1), ('196.160.4.19', 1), ('197.161.4.9', 1), ('183.167.2.13', 1), ('186.167.2.1', 1), ('193.161.2.11', 1), ('183.162.5.8', 1), ('193.164.5.13', 1), ('182.168.6.19', 1), ('195.169.3.6', 1), ('187.165.8.7', 1), ('186.163.1.14', 1), ('199.165.4.9', 1), ('198.161.6.31', 1), ('185.161.4.20', 1), ('192.160.4.19', 1), ('196.169.3.20', 1), ('199.165.1.6', 1), ('195.166.6.26', 1), ('200.168.3.3', 1), ('185.161.6.9', 1), ('181.169.1.12', 1), ('191.162.2.17', 1), ('186.167.1.12', 1), ('192.165.7.11', 1), ('198.164.1.28', 1), ('198.160.8.15', 1), ('183.160.5.8', 1), ('185.164.6.1', 1), ('182.163.2.13', 1), ('183.170.8.8', 1), ('200.166.3.20', 1), ('193.169.6.14', 1), ('196.163.6.20', 2), ('194.168.4.12', 1), ('182.164.1.3', 1), ('194.168.3.11', 1), ('181.161.3.9', 1), ('181.169.6.16', 1), ('183.168.2.26', 1), ('194.166.8.9', 1), ('194.162.3.9', 1), ('181.165.3.11', 1), ('194.167.6.4', 1), ('199.166.6.22', 1), ('187.169.3.28', 1), ('199.164.5.4', 1), ('193.162.2.27', 1), ('183.168.2.2', 1), ('193.168.3.30', 1), ('200.167.5.5', 1), ('199.161.7.13', 1), ('189.161.2.11', 1), ('188.164.3.9', 1), ('184.169.3.32', 1), ('181.165.8.28', 2), ('184.162.7.2', 1), ('191.167.6.24', 1), ('198.166.7.3', 1), ('196.169.6.13', 1), ('184.166.2.22', 1), ('193.167.5.10', 1), ('198.166.3.7', 1), ('194.165.4.8', 1), ('188.166.6.19', 1), ('194.161.4.15', 1), ('191.167.6.14', 1), ('195.167.4.10', 1), ('199.168.7.18', 1), ('191.161.7.27', 1), ('180.163.7.28', 1), ('194.166.2.2', 1), ('183.170.7.10', 1), ('183.164.8.17', 1), ('198.164.2.27', 1), ('182.169.2.19', 1), ('200.166.2.2', 1), ('190.165.7.15', 1), ('193.166.8.12', 1), ('183.164.5.16', 1), ('187.166.1.6', 1), ('195.160.6.20', 2), ('185.170.5.26', 1), ('194.170.5.6', 1), ('197.164.8.3', 1), ('194.166.8.30', 1), ('194.163.2.6', 1), ('180.168.8.13', 1), ('185.169.6.15', 1), ('193.160.5.9', 1), ('191.164.5.9', 1), ('184.170.2.2', 1), ('196.168.4.22', 1), ('187.162.7.7', 1), ('193.168.8.8', 1), ('185.166.7.17', 1), ('188.168.1.26', 1), ('187.164.2.1', 1), ('180.166.2.20', 1), ('187.169.7.21', 1), ('198.168.8.12', 1), ('184.160.6.15', 1), ('200.168.6.29', 1), ('181.161.8.15', 1), ('188.166.7.18', 1), ('184.162.3.28', 1), ('192.169.3.30', 1), ('190.167.7.22', 1), ('199.165.1.22', 1), ('198.161.2.5', 1), ('200.167.4.1', 1), ('181.162.3.5', 1), ('182.167.1.4', 1), ('192.170.5.27', 1), ('192.163.5.30', 2), ('197.168.7.26', 1), ('196.162.4.30', 1), ('200.169.5.13', 1), ('180.170.6.32', 1), ('196.164.6.12', 1), ('184.164.3.8', 1), ('184.167.5.3', 1), ('192.161.3.1', 1), ('195.164.2.31', 1), ('195.169.3.21', 1), ('183.170.7.2', 1), ('184.166.2.10', 1), ('182.166.3.21', 1), ('191.161.8.1', 1), ('194.161.3.26', 1), ('188.163.2.22', 1), ('192.161.7.8', 1), ('189.164.7.26', 1), ('193.168.1.7', 1), ('197.164.4.20', 1), ('192.170.7.15', 1), ('189.167.2.27', 2), ('185.165.5.11', 1), ('198.163.3.20', 1), ('194.163.5.1', 1), ('191.163.2.9', 1), ('200.167.3.10', 1), ('182.161.8.14', 1), ('200.161.8.3', 1), ('194.163.3.25', 1), ('183.170.7.3', 1), ('192.165.1.13', 1), ('198.168.2.5', 1), ('187.160.6.25', 1), ('181.160.7.31', 1), ('180.168.1.7', 1), ( ...

# %% [markdown]
# # NAMEDTUPLE

# %% [markdown]
# ## создадим персонажа игры с характеристиками

# %% [markdown]
# #### вариант 1

# %%
hero_1 = ('Vaar', 'Lendu', 100, 0.0, 250)
print(hero_1[1])
# Out:
# Lendu

# %% [markdown]
# неудобно обращаться по индексам

# %% [markdown]
# #### вариант 2

# %%
class Hero:
    def __init__(self, name, race, health, mana, strength):
        self.name = name
        self.race = race
        self.health = health
        self.mana = mana
        self.strength = strength

hero_2 = Hero('Vaar', 'Lendu', 100, 0.0, 250)
print(hero_2.race)
# Out:
# Lendu

# %% [markdown]
# #### вариант 3

# %%
from collections import namedtuple


New_Hero = namedtuple('New_Hero', ('name, race, health, mana, strength'))  # New_Hero - название класса 
# New_Hero = namedtuple('New_Hero', ('name race health mana strength'))  # можно и без запятых
hero_3 = New_Hero('Vaar', 'Lendu', 100, 0.0, 250)
print(hero_3.race)
# Out:
# Lendu

# %% [markdown]
# #### вариант 4

# %%
from collections import namedtuple

characteristics = ['name', 'race', 'health', 'mana', 'strength']  # передаём характеристики в виде списка
New_Hero = namedtuple('New_Hero', characteristics)

hero_4 = New_Hero('Vaar', 'Lendu', 100, 0.0, 250)
print(hero_4.race)
# Out:
# Lendu

# %% [markdown]
# #### вариант 5

# %%
from collections import namedtuple

characteristics = ['name', '3race', 'health', '_mana', 'strength']
New_Hero = namedtuple('New_Hero', characteristics, rename=True)  # rename=True - преименовывает неадекватные имена

hero_4 = New_Hero('Vaar', 'Lendu', 100, 0.0, 250)
print(hero_4)  # _1 и _3 вместо 3race и _mana
# Out:
# New_Hero(name='Vaar', _1='Lendu', health=100, _3=0.0, strength=250)

# %% [markdown]
# ## создадим координаты точки в пространстве

# %%
from collections import namedtuple

Point = namedtuple('Point', 'x, y, z')

p_1 = Point(2, z=3, y=4)
print(p_1)
# Out:
# Point(x=2, y=4, z=3)

# %%
t = [5, 10, 15]
p_2 = Point._make(t)
print(p_2)
# Out:
# Point(x=5, y=10, z=15)

# %% [markdown]
# #### ._asdict

# %%
p_2_asdict = p_2._asdict()
print(p_2_asdict)
# Out:
# {'x': 5, 'y': 10, 'z': 15}

# %% [markdown]
# #### ._replace(...)

# %%
p_2
# Out:
# Point(x=5, y=10, z=15)

# %%
p_3 = p_2._replace(x=6)
print(p_3)
# Out:
# Point(x=6, y=10, z=15)

# %% [markdown]
# #### ._fields

# %%
print(p_3._fields)
# Out:
# ('x', 'y', 'z')

# %% [markdown]
# #### defaults

# %%
from collections import namedtuple

New_Point = namedtuple('New_Point', 'x, y, z', defaults=[33, 22])  # здесь в defaults заданы значения для y и z по умолчанию
p_4 = New_Point(5)

# %%
print(p_4)
# Out:
# New_Point(x=5, y=33, z=22)

# %% [markdown]
# #### ._fields_defaults

# %%
print(p_4._fields_defaults)
# Out:
# {'y': 33, 'z': 22}

# %% [markdown]
# #### создание именованного кортежа на основании словаря

# %%
my_dict = {'x': 1, 'y': 2, 'z': 3}
p_5 = New_Point(**my_dict)
print(p_5)
# Out:
# New_Point(x=1, y=2, z=3)

# %% [markdown]
# # CHAINMAP

# %%
from collections import ChainMap

# %%
d_1 = {'a': 1, 'b': 2, 'c': 3}
d_2 = {'a': 10, 'b': 20, 'd': 30}

# %%
d_map = ChainMap(d_1, d_2)
print(d_map)
d_2['a'] = 100
print(d_map)  # изменили d_2, а изменилась и коллекция ChainMap, т.к. используется ссылочная структура данных
# Out:
# ChainMap({'a': 1, 'b': 2, 'c': 3}, {'a': 10, 'b': 20, 'd': 30})
# ChainMap({'a': 1, 'b': 2, 'c': 3}, {'a': 100, 'b': 20, 'd': 30})

# %%
print(d_map['a'])  # ссылается на 'a' первого объекта, т.к. он первый
print(d_map['d'])  # ссылается на 'd' второго объекта, т.к. в первом объектн 'd' нет
# Out:
# 1
# 30

# %% [markdown]
# #### .new_child()

# %%
x = d_map.new_child()
print(x)  # добавился пустой словарь
# Out:
# ChainMap({}, {'a': 1, 'b': 2, 'c': 3}, {'a': 100, 'b': 20, 'd': 30})

# %% [markdown]
# #### .maps[...]

# %%
print(x.maps[0])  # обращение к первому словарю
print(x.maps[-1])  # обращение к последнему словарю
# Out:
# {}
# {'a': 100, 'b': 20, 'd': 30}

# %% [markdown]
# #### .parents

# %%
print(x.parents)
# Out:
# ChainMap({'a': 1, 'b': 2, 'c': 3}, {'a': 100, 'b': 20, 'd': 30})

# %%
x = d_map.new_child({'a': 100, 'b': 200, 'c': 300, 'd': 400})
print(x)
print(x.parents)
# Out:
# ChainMap({'a': 100, 'b': 200, 'c': 300, 'd': 400}, {'a': 1, 'b': 2, 'c': 3}, {'a': 100, 'b': 20, 'd': 30})
# ChainMap({'a': 1, 'b': 2, 'c': 3}, {'a': 100, 'b': 20, 'd': 30})

# %% [markdown]
# #### добавление элемента / изменение значения элемента

# %%
y = d_map.new_child()
print(y)
print(y['a'])
y['a'] = 1
print(y)  # в первом словаре не было 'a', поэтому 'a' добавился в первый словарь
y['a'] = 2
print(y)
# Out:
# ChainMap({}, {'a': 1, 'b': 2, 'c': 3}, {'a': 100, 'b': 20, 'd': 30})
# 1
# ChainMap({'a': 1}, {'a': 1, 'b': 2, 'c': 3}, {'a': 100, 'b': 20, 'd': 30})
# ChainMap({'a': 2}, {'a': 1, 'b': 2, 'c': 3}, {'a': 100, 'b': 20, 'd': 30})

# %%
print(list(y))
print(list(y.values()))
# Out:
# ['a', 'b', 'd', 'c']
# [2, 2, 30, 3]

# %%
import argparse
from collections import ChainMap


defaults = {'ip': 'localhost', 'port': 7777}

parser = argparse.ArgumentParser()
parser.add_argument('-i', '--ip')
parser.add_argument('-p', '--port')

args = parser.parse_args()
new_dict = {key: value for key, value in vars(args).items() if value}

settings = ChainMap(new_dict, defaults)
print(settings['ip'])
print(settings['port'])
# Out:
# usage: ipykernel_launcher.py [-h] [-i IP] [-p PORT]
# ipykernel_launcher.py: error: unrecognized arguments: -f C:\Users\fross\AppData\Roaming\jupyter\runtime\kernel-49dd8a5e-e218-429c-b4b5-4bda57efaaec.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
